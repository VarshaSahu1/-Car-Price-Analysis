# %% [markdown]
# # Import library

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
from warnings import filterwarnings
filterwarnings('ignore')
pd.set_option('display.max_rows',10)

# %%
df= pd.read_csv("Quikr car price prediction.csv")
df.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
df.shape  # it's show the how many rows and coloumns
# Out:
# (892, 6)

# %%
# Data Exploration (EDA) ,identyfy the problrms

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
 # View the dataset:

# %%
df.describe()  
df.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
df["Price"].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
for i in df.columns: 
    print(i)
    print (df["Price"].unique())
# Out:
# name
# ['80,000' '4,25,000' 'Ask For Price' '3,25,000' '5,75,000' '1,75,000'
#  '1,90,000' '8,30,000' '2,50,000' '1,82,000' '3,15,000' '4,15,000'
#  '3,20,000' '10,00,000' '5,00,000' '3,50,000' '1,60,000' '3,10,000'
#  '75,000' '1,00,000' '2,90,000' '95,000' '1,80,000' '3,85,000' '1,05,000'
#  '6,50,000' '6,89,999' '4,48,000' '5,49,000' '5,01,000' '4,89,999'
#  '2,80,000' '3,49,999' '2,84,999' '3,45,000' '4,99,999' '2,35,000'
#  '2,49,999' '14,75,000' '3,95,000' '2,20,000' '1,70,000' '85,000'
#  '2,00,000' '5,70,000' '1,10,000' '4,48,999' '18,91,111' '1,59,500'
#  '3,44,999' '4,49,999' '8,65,000' '6,99,000' '3,75,000' '2,24,999'
#  '12,00,000' '1,95,000' '3,51,000' '2,40,000' '90,000' '1,55,000'
#  '6,00,000' '1,89,500' '2,10,000' '3,90,000' '1,35,000' '16,00,000'
#  '7,01,000' '2,65,000' '5,25,000' '3,72,000' '6,35,000' '5,50,000'
#  '4,85,000' '3,29,500' '2,51,111' '5,69,999' '69,999' '2,99,999'
#  '3,99,999' '4,50,000' '2,70,000' '1,58,400' '1,79,000' '1,25,000'
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 887    False
# 888    False
# 889    False
# 890    False
# 891    False
# Length: 892, dtype: bool

# %%
df[df.duplicated()]
# Out:
#                                      name   company  year     Price  \
# 14   Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007    80,000
# 15                Mahindra Jeep CL550 MDI  Mahindra  2006  4,25,000
# 20                   Mahindra Scorpio S10  Mahindra  2016  3,50,000
# 24                 Hyundai i20 Sportz 1.2   Hyundai  2012  1,00,000
# 25                 Hyundai i20 Sportz 1.2   Hyundai  2012  1,00,000
# ..                                    ...       ...   ...       ...
# 626               Tata Sumo Gold EX BS IV      Tata  2012  2,10,000
# 641         Maruti Suzuki Swift VDi BS IV    Maruti  2012  2,80,000
# 727                   Mahindra Scorpio S4  Mahindra  2015  8,65,000
# 861            Hyundai Getz Prime 1.3 GLX   Hyundai  2009  1,15,000
# 880    Maruti Suzuki Swift Dzire Tour VDi    Maruti  2009  2,50,000
#
#      kms_driven fuel_type
# 14   45,000 kms    Petrol
# 15       40 kms    Diesel
# 20   43,000 kms    Diesel
# 24   55,000 kms    Petrol
# ...

# %%
df['company'].value_counts()  # For categorical columns
# Out:
# company
# Maruti      235
# Hyundai     145
# Mahindra    100
# Tata         74
# Honda        61
#            ...
# Swift         1
# URJENT        1
# selling       1
# Yamaha        1
# Tara          1
# Name: count, Length: 48, dtype: int64

# %%
df.drop_duplicates()
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
df.shape
# Out:
# (892, 6)

# %%
df.drop_duplicates(inplace=True)    # Remove duplicates

# %%
df.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    50
# fuel_type     53
# dtype: int64

# %%
df1=df.copy()     # Save the copy, no changes in original copy it's like shallow copy and deep copy 
df1
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
# df.year.str.isnumeric()
df[df.year.str.isnumeric()]
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 886                    Toyota Corolla Altis     Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#        kms_driven fuel_type
# ...

# %%
df=df[df.year.str.isnumeric()]  # converting data type string into integer

# %%
df.shape
# Out:
# (749, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 749 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        749 non-null    object
#  1   company     749 non-null    object
#  2   year        749 non-null    object
#  3   Price       749 non-null    object
#  4   kms_driven  748 non-null    object
#  5   fuel_type   745 non-null    object
# dtypes: object(6)
# memory usage: 41.0+ KB

# %%
a ='1234'
print(a.isnumeric())
# Out:
# True

# %%
df.year.dtype
# Out:
# dtype('O')

# %%
df['year']=df.year.astype('int')

# %%
df['Price'].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
df.Price.str.replace(',','').str.isnumeric()
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 886     True
# 888     True
# 889     True
# 890     True
# 891     True
# Name: Price, Length: 749, dtype: bool

# %%
df['Price']=df.Price.str.replace(',','')
df
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007          80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006         425000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014         325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014         575000
# ..                                      ...        ...   ...            ...
# 886                    Toyota Corolla Altis     Toyota  2009         300000
# 888                     Tata Zest XM Diesel       Tata  2018         260000
# 889                      Mahindra Quanto C8   Mahindra  2013         390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014         180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014         160000
#
#        kms_driven fuel_type
# ...

# %%
df['Price']=df.Price.astype('int')

# %%
df=df[df.Price.str.isnumeric()]

# %%
df.Price.dtype
# Out:
# dtype('int32')

# %%
# KMS

# %%
df['kms_driven'].unique()

# %%
df.columns

# %%
df['kms_driven']=df['kms_driven'].apply(lambda x:x.replace(',','').split()[0])
df

# %%
df=df[df.kms_driven.str.isnumeric()]

# %%
df['kms_driven']=df.kms_driven.astype('int')

# %%
df.info()

# %%
df.isnull().sum()

# %%
df['fuel_type'].value_counts()

# %%
df[df.isnull().any(axis=1)]   # It's check where is null value

# %%
df[df['company']== 'Toyota'].fuel_type.mode()

# %%
df=df['fuel_type'].fillna('Diesel',inplace=True)

# %%
sns.boxplot(x=df['Price'])
# Out:
# <Axes: xlabel='Price'>

# %%
df[df['Price']>400000]
# Out:
#                                  name    company  year    Price    kms_driven  \
# 1             Mahindra Jeep CL550 MDI   Mahindra  2006   425000        40 kms
# 4    Ford EcoSport Titanium 1.5L TDCi       Ford  2014   575000    36,000 kms
# 8    Ford EcoSport Ambiente 1.5L TDCi       Ford  2016   830000    24,530 kms
# 12        Hyundai Elite i20 Magna 1.2    Hyundai  2014   415000    32,000 kms
# 16                            Audi A8       Audi  2017  1000000     4,000 kms
# ..                                ...        ...   ...      ...           ...
# 872              Chevrolet Tavera Neo  Chevrolet  2007   465000  1,00,800 kms
# 874                 Hyundai Elite i20    Hyundai  2018   510000     2,100 kms
# 875              Honda City VX Petrol      Honda  2016   860000    95,000 kms
# 876               Maruti Suzuki Dzire     Maruti  2016   450000     2,500 kms
# 878    Mercedes Benz C Class 200 K MT   Mercedes  2006   500001    15,000 kms
#
#     fuel_type
# 1      Diesel
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 727 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        727 non-null    object
#  1   company     727 non-null    object
#  2   year        727 non-null    int32
#  3   Price       727 non-null    int32
#  4   kms_driven  727 non-null    object
#  5   fuel_type   724 non-null    object
# dtypes: int32(2), object(4)
# memory usage: 34.1+ KB

# %%
df[df['name']=='Mahindra XUV500 W6']
# Out:
#                    name   company  year    Price  kms_driven fuel_type
# 484  Mahindra XUV500 W6  Mahindra  2013   548900  49,800 kms    Diesel
# 562  Mahindra XUV500 W6  Mahindra  2014  8500003  45,000 kms    Diesel
# 586  Mahindra XUV500 W6  Mahindra  2013   549900  52,800 kms    Diesel

# %%
df.loc[df['Price']==8500003, 'Price'] = 80000

# %%
df.company.unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Ford', 'Maruti', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat', 'Force',
#        'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'], dtype=object)

# %%
df.groupby('company')['Price'].mean()
# Out:
# company
# Audi          1.554700e+06
# BMW           1.049875e+06
# Chevrolet     1.957617e+05
# Datsun        2.591663e+05
# Fiat          1.215000e+05
#                   ...
# Skoda         2.764488e+05
# Tata          1.969025e+05
# Toyota        4.958570e+05
# Volkswagen    4.211762e+05
# Volvo         1.850000e+06
# Name: Price, Length: 25, dtype: float64

# %%
df.groupby('fuel_type')['Price'].mean()
# Out:
# fuel_type
# Diesel    490594.478916
# LPG       205000.000000
# Petrol    308312.964103
# Name: Price, dtype: float64
